# %%
import pandas as pd

a=pd.read_table("http://bit.ly/uforeports",sep=",")

# %%
a.rename(columns= {"Colors Reported":"Colors_Reported",'Shape Reported':'Shape_Reported'},inplace = True)
hdr= ['Citys', 'Colors Reported', 'Shapea Reported', 'State', 'Time']
a.columns = a.columns.str.replace(" ","_")
a
# Out:
#                       Citys Colors_Reported Shapea_Reported State  \
# 0                    Ithaca             NaN        TRIANGLE    NY
# 1               Willingboro             NaN           OTHER    NJ
# 2                   Holyoke             NaN            OVAL    CO
# 3                   Abilene             NaN            DISK    KS
# 4      New York Worlds Fair             NaN           LIGHT    NY
# 5               Valley City             NaN            DISK    ND
# 6               Crater Lake             NaN          CIRCLE    CA
# 7                      Alma             NaN            DISK    MI
# 8                   Eklutna             NaN           CIGAR    AK
# 9                   Hubbard             NaN        CYLINDER    OR
# 10                  Fontana             NaN           LIGHT    CA
# 11                 Waterloo             NaN        FIREBALL    AL
# 12                   Belton             RED          SPHERE    SC
# ...

# %%
a.drop("Colors_Reported",axis=1,inplace = True)
a.drop(44,axis=0,inplace = True)

# %%
a=pd.read_csv("http://bit.ly/imdbratings",usecols=[0,4])

# %%
a.sort_values(["star_rating","duration"],ascending=False)

# %%
a.loc[(a.duration>200) & (a.genre.isin(["Crime","Drama"]))]
# Out:
#      star_rating                        title content_rating  genre  duration  \
# 17           8.7                Seven Samurai        UNRATED  Drama       207
# 78           8.4  Once Upon a Time in America              R  Crime       229
# 157          8.2           Gone with the Wind              G  Drama       238
# 476          7.8                       Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
import numpy as np
a= pd.read_csv("http://bit.ly/drinksbycountry")
a.select_dtypes(include=[np.number])
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# 5              102              128             45
# 6              193               25            221
# 7               21              179             11
# 8              261               72            212
# 9              279               75            191
# 10              21               46              5
# 11             122              176             51
# 12              42               63              7
# 13               0                0              0
# 14             143              173             36
# 15             142              373             42
# 16             295               84            212
# ...

# %%
a.country =a.country.str.upper()
a[a.continent.str.contains("ri")]
a[a.country.isin(["ALBANIA"])]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 1  ALBANIA             89              132             54
#
#    total_litres_of_pure_alcohol continent
# 1                           4.9    Europe

# %%
# %matplotlib inline
a.groupby("continent").beer_servings.agg(["mean","max","min"]).plot(kind="line")

# %%
pd.crosstab(a.country,a.continent)
# Out:
# continent             Africa  Asia  Europe  North America  Oceania  \
# country
# AFGHANISTAN                0     1       0              0        0
# ALBANIA                    0     0       1              0        0
# ALGERIA                    1     0       0              0        0
# ANDORRA                    0     0       1              0        0
# ANGOLA                     1     0       0              0        0
# ANTIGUA & BARBUDA          0     0       0              1        0
# ARGENTINA                  0     0       0              0        0
# ARMENIA                    0     0       1              0        0
# AUSTRALIA                  0     0       0              0        1
# AUSTRIA                    0     0       1              0        0
# AZERBAIJAN                 0     0       1              0        0
# BAHAMAS                    0     0       0              1        0
# BAHRAIN                    0     1       0              0        0
# ...
